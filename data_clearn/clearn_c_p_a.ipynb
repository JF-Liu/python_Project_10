# %%
import os, jieba, json, re
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:/pytel_data/outhet_excel_2/ikeamaster_ver7_cl_f5.csv',encoding='utf8')

# %%
df
# Out:
#      Unnamed: 0 Product_number  \
# 0             0     004.243.63
# 1             1     091.838.68
# 2             2     092.792.91
# 3             3     391.987.88
# 4             4     403.201.32
# ..          ...            ...
# 716         716     992.879.89
# 717         717     992.882.91
# 718         718     993.308.22
# 719         719     993.313.03
# 720         720     993.313.55
#
#                                                    url  \
# 0    https://www.ikea.com.tw/zh/products/beds/flexi...
# 1    https://www.ikea.com.tw/zh/products/beds/flexi...
# 2    https://www.ikea.com.tw/zh/products/beds/flexi...
# 3    https://www.ikea.com.tw/zh/products/beds/flexi...
# 4    https://www.ikea.com.tw/zh/products/beds/flexi...
# ..                                                 ...
# 716  https://www.ikea.com.tw/zh/products/office-wor...
# 717  https://www.ikea.com.tw/zh/products/office-wor...
# 718  https://www.ikea.com.tw/zh/products/home-works...
# ...

# %%
df_c_a = df[['Product_number', 'summary', 'category', 'color_1', 'color_2', 'color_3']]

# %%
df_c_a
# Out:
#     Product_number                      summary    category color_1 color_2  \
# 0       004.243.63                   坐臥兩用床框, 黑色        beds      黑色    None
# 1       091.838.68  坐臥兩用床附2抽/2床墊, 白色/husvika 偏硬        beds      白色    None
# 2       092.792.91     坐臥兩用床附2床墊, 黑色/husvika 偏硬        beds      黑色    None
# 3       391.987.88  坐臥兩用床附2抽/2床墊, 白色/malfors 偏硬        beds      白色    None
# 4       403.201.32               坐臥兩用床框附2抽屜, 白色        beds      白色    None
# ..             ...                          ...         ...     ...     ...
# 716     992.879.89           櫃台桌, 黑色/實木貼皮 梣木/白色  work-desks      黑色      梣木
# 717     992.882.91        升降式櫃台桌, 黑色/實木貼皮 梣木/白色  work-desks      黑色      梣木
# 718     993.308.22              桌子, 白色 染白橡木紋/藍色  work-desks   染白橡木紋      藍色
# 719     993.313.03                   桌子, 淺灰色/白色  work-desks     淺灰色      白色
# 720     993.313.55                   桌子, 淺灰色/白色  work-desks     淺灰色      白色
#
#     color_3
# 0      None
# 1      None
# 2      None
# ...

# %%
df_c_a.to_csv(r'D:/pytel_data/outhet_excel_2/p_c_a/df_c_a.csv', encoding='utf-8')

# %%
df_p_a = df[['Product_number', 'summary', 'category', 'price']]

# %%
df_p_a
# Out:
#     Product_number                      summary    category  price
# 0       004.243.63                   坐臥兩用床框, 黑色        beds   6990
# 1       091.838.68  坐臥兩用床附2抽/2床墊, 白色/husvika 偏硬        beds  16880
# 2       092.792.91     坐臥兩用床附2床墊, 黑色/husvika 偏硬        beds  10970
# 3       391.987.88  坐臥兩用床附2抽/2床墊, 白色/malfors 偏硬        beds  14788
# 4       403.201.32               坐臥兩用床框附2抽屜, 白色        beds  12900
# ..             ...                          ...         ...    ...
# 716     992.879.89           櫃台桌, 黑色/實木貼皮 梣木/白色  work-desks   9490
# 717     992.882.91        升降式櫃台桌, 黑色/實木貼皮 梣木/白色  work-desks  23990
# 718     993.308.22              桌子, 白色 染白橡木紋/藍色  work-desks   1090
# 719     993.313.03                   桌子, 淺灰色/白色  work-desks    990
# 720     993.313.55                   桌子, 淺灰色/白色  work-desks   2490
#
# [721 rows x 4 columns]

# %%
df_p_a.to_csv(r'D:/pytel_data/outhet_excel_2/p_c_a/df_p_a.csv', encoding='utf-8')
